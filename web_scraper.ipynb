# %%
import requests
import os
import webbrowser 
import sys

# %%
response = requests.get('https://realpython.com/python-web-scraping-practical-introduction/').text.encode('utf8').decode('ascii', 'ignore')

# %%
print(response)
# Out:
# <!doctype html>
# <html lang="en">
# <head>
# <link href="https://files.realpython.com" rel="preconnect">
# <title>A Practical Introduction to Web Scraping in Python  Real Python</title>
# <meta name="author" content="Real Python">
# <meta name="description" content="In this tutorial, you&#x27;ll learn all about web scraping in Python. You&#x27;ll see how to parse data from websites and interact with HTML forms using tools such as Beautiful Soup and MechanicalSoup.">
# <meta name="keywords" content="">
# <meta charset="utf-8">
# <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
# <link rel="stylesheet" href="/static/gfonts/font.32be62914940.css">
# <link rel="stylesheet" href="/static/realpython.min.60164abeec2e.css">
# <link rel="canonical" href="https://realpython.com/python-web-scraping-practical-introduction/">
# <meta name="twitter:card" content="summary_large_image">
# ...

# %%
url = 'C:/Users/Benjamin/Desktop/html_scrapes/page.html'

try:
    os.mkdir(url)
except Exception as er:
    print(f'exception: {er}')

try:
    with open(url, 'w') as f:
        f.write(response)
except Exception as er:
    print(f'exception: {er}')
# Out:
# exception: [WinError 183] Cannot create a file when that file already exists: 'C:/Users/Benjamin/Desktop/html_scrapes/page.html'

# %%
try: # should work on Windows
    os.startfile('C:/Users/Benjamin/Desktop/html_scrapes/page.html')
except AttributeError:
    try: # should work on MacOS and most linux versions
        subprocess.call(['open', url])
    except:
        print('Could not open URL')

# %%
# Notice that you username and token are required here
r = requests.post(
  "https://api.github.com/users/<username>/repos?access_token=<generated token>", 
  data={
  "name": "Hello-World",
  "description": "This is your first repository",
  "homepage": "https://github.com",
  "private": False,
  "has_issues": True,
  "has_projects": True,
  "has_wiki": True
})

if r.status_code != 200:
  sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\Benjamin\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3351: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
